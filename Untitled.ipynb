# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas
from scipy.optimize import curve_fit 
from numpy import log, exp

pandas.options.display.max_rows = 10000

df = pandas.read_csv( 'data/assay_data_clean.csv' )

temp_key = pandas.read_csv( 'data/temp_key.csv' )
temp_key.index = temp_key.Well

df['temp'] = df.well.str[0].map( temp_key.Kelvin.to_dict() ) 
df.dropna( inplace=True )
df.head()
print df.rate.dtype
# Out:
# float64

# %%
# plot the raw data
def plot_mutant( mutant_df ):  
    
    mutant_df['rate'] = mutant_df.rate / mutant_df.rate.max()
    
    plt.figure( figsize=(1,1) )
    plt.scatter( mutant_df.temp, mutant_df.rate, alpha=0.7, color='black', marker='.' )
    plt.xlabel( '$T$' )
    plt.ylabel( '$min^{-1}$')
    plt.xticks( [ 305, 315, 325 ] )
    plt.yticks( [ 0, 0.5, 1 ] )
    plt.title( mutant_df.mutant.unique()[0] )

    reg = LinearRegression()
    reg.fit( mutant_df.temp.reshape(-1, 1), mutant_df.rate )
    plt.plot( mutant_df.temp, reg.predict( mutant_df.temp.reshape(-1, 1) ), color='black' )
    
    plt.show()
    plt.close()
    
    params = { 'tm': reg.coef_[0] }
    return pandas.Series( params )
    
fits = df.groupby( by='mutant' ).apply( plot_mutant )
fits.head()
# Out:
#               tm
# mutant
# A195S  -0.053778
# A356A  -0.061794
# A357A  -0.052266
# A408A  -0.062410
# C167Q  -0.057187

# %%
fits['native'] = fits.index.str[0]
fits['designed'] = fits.index.str[-1]
fits['position'] = fits.index.str[1:-1].astype( int )
fits['mutant'] = fits.index
fits.head()
# Out:
#               tm native designed  position mutant
# mutant
# A195S  -0.053778      A        S       195  A195S
# A356A  -0.061794      A        A       356  A356A
# A357A  -0.052266      A        A       357  A357A
# A408A  -0.062410      A        A       408  A408A
# C167Q  -0.057187      C        Q       167  C167Q

# %%
plt.figure( figsize=(88,3) )
plt.plot( (0,444), (0,0), alpha=0.1 )

plt.bar( fits.position, fits.tm, width=1, linewidth=0, tick_label=fits.native, alpha=0.1 )
plt.ylim( ( -0.25, .25 ) )

for name, series in fits.iterrows():
    plt.text( series.position, series.tm, series.designed )

# %%
# fake data

from numpy import random, array 
from Bio.Alphabet.IUPAC import IUPACProtein
import screed

for record in screed.open( 'data/bglb.pep' ):
    seq = list( record.sequence )
    length = len( seq )

ts2 = [ random.choice( list( IUPACProtein.letters ) ) for i in range( length ) ]
i = [ random.choice( range( length ) ) for i in range( length ) ]
d = { 'native': seq, 'mutant': ts2, 'tm': random.random( length ) - 0.5, 'position': i }
df = pandas.DataFrame(d)
print df.head()
# Out:
#   mutant native  position        tm
# 0      S      N       115 -0.203269
# 1      M      T       227  0.289930
# 2      I      F       114 -0.209522
# 3      M      I        84 -0.201450
# 4      R      F       251  0.221061

# %%
plt.figure( figsize=(88,3) )
plt.bar( df.position, df.tm, width=1, linewidth=0, tick_label=df.native, alpha=0.1 )
for name, series in df.iterrows():
    plt.text( series.position, series.tm, series.mutant )
